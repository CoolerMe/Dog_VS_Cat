# %% [markdown]
# #                                           神经网络完成 dog vs cat 项目
# #### 作者: 曾烨烨
# #### 开始时间 : 2018/6/1
# #### 结束时间 :

# %%
#首先加载来自Kaggle的数据
# !kg download -u cooldeveloper43 -p MYSJTX983713522 -c dogs-vs-cats-redux-kernels-edition  -f train.zip
# !kg download -u cooldeveloper43 -p MYSJTX983713522 -c dogs-vs-cats-redux-kernels-edition  -f test.zip
# Out:
# Starting new HTTPS connection (1): www.kaggle.com
# downloading https://www.kaggle.com/c/dogs-vs-cats-redux-kernels-edition/download/train.zip
#
# Starting new HTTPS connection (1): storage.googleapis.com
# train.zip already downloaded !
# Starting new HTTPS connection (1): www.kaggle.com
# downloading https://www.kaggle.com/c/dogs-vs-cats-redux-kernels-edition/download/test.zip
#
# Starting new HTTPS connection (1): storage.googleapis.com
# test.zip 100% |#####################################| Time: 0:00:06  45.0 MiB/s

# %%
#先加载所有的train数据
from sklearn.datasets import load_files
from keras.utils import np_utils
import numpy as np
import os

# #加载所有的数组,此处应该有更优雅的实现的
def load_data(path):
    file_names=os.listdir(path)
    file_targets=[]
    for file_name in file_names:
        file_targets.append('dog' in file_name)
    data_files=np.array(file_names)
    data_targets=np.array(file_targets)
    return data_files,data_targets

data_files,data_targets=load_data('./train')
print(data_files[0])
# Out:
# Using TensorFlow backend.
# cat.0.jpg

# %%
dogs =['n02085620','n02085782','n02085936','n02086079'
,'n02086240','n02086646','n02086910','n02087046'
,'n02087394','n02088094','n02088238','n02088364'
,'n02088466','n02088632','n02089078','n02089867'
,'n02089973','n02090379','n02090622','n02090721'
,'n02091032','n02091134','n02091244','n02091467'
,'n02091635','n02091831','n02092002','n02092339'
,'n02093256','n02093428','n02093647','n02093754'
,'n02093859','n02093991','n02094114','n02094258'
,'n02094433','n02095314','n02095570','n02095889'
,'n02096051','n02096177','n02096294','n02096437'
,'n02096585','n02097047','n02097130','n02097209'
,'n02097298','n02097474','n02097658','n02098105'
,'n02098286','n02098413','n02099267','n02099429'
,'n02099601','n02099712','n02099849','n02100236'
,'n02100583','n02100735','n02100877','n02101006'
,'n02101388','n02101556','n02102040','n02102177'
,'n02102318','n02102480','n02102973','n02104029'
,'n02104365','n02105056','n02105162','n02105251'
,'n02105412','n02105505','n02105641','n02105855'
,'n02106030','n02106166','n02106382','n02106550'
,'n02106662','n02107142','n02107312','n02107574'
,'n02107683','n02107908','n02108000','n02108089'
,'n02108422','n02108551','n02108915','n02109047'
,'n02109525','n02109961','n02110063','n02110185'
,'n02110341','n02110627','n02110806','n02110958'
,'n02111129','n02111277','n02111500','n02111889'
,'n02112018','n02112137','n02112350','n02112706'
,'n02113023','n02113186','n02113624','n02113712'
,'n02113799','n02113978']

cats=['n02123045','n02123159','n02123394','n02123597'
,'n02124075','n02125311','n02127052']

#[上面数据来自知乎上某人关于ImageNet预测的品种的猫狗的分别可能](https://zhuanlan.zhihu.com/p/34068451)

# %%
#使用多个模型来清除不正常的数据
# %matplotlib inline 
from keras.applications.resnet50 import ResNet50
from keras.preprocessing import image
from keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np
import matplotlib.pyplot as plt           
import matplotlib.image as mpimg # mpimg 用于读取图片

def clean_up_dataset(model,threshold=10,size=100):
        '''使用特定的模型来预测图片是否属于猫狗'''
        #保存输出不正常的路径
        path_list=[]
        for i in range(len(data_files)):
            file_name=data_files[i]
            is_dog=data_targets[i]
            img_path=os.path.join('./train',file_name)
            img=image.load_img(img_path,target_size=(224,224))
            x=image.img_to_array(img)
            x=np.expand_dims(x,axis=0)
            x=preprocess_input(x)
            
            #进行预测
            prediction=model.predict(x)
            result=np.array(decode_predictions(prediction,top=threshold)[0])
            #只留下预测的图片的实物编码即可
            result=result[:,0]
            
            bad_image=True
            if is_dog:
                #预测的种类是否存在dogs中
                if np.in1d(result,dogs).sum()>0:
                    bad_image=False
                    continue
            else:
                #预测的种类是否存在cats中
                if np.in1d(result,cats).sum()>0:
                    bad_image=False
                    continue
                    
            #展示坏的图片
            if bad_image:
                print('This picture has some problem:',file_name)
                #保存不正常图片的路径
                print(img_path)
                path_list.append(img_path)
                #展示图片
                picture=mpimg.imread('./train/'+file_name)
                plt.imshow(picture)
                plt.show()
            #只测试指定数量的图片,到了GPU服务器,就修改成全部
            if i>=size:
                break;
        return path_list

# %%
#使用ResNet50检测异常数据
model = ResNet50(weights='imagenet')
bad_pictures=clean_up_dataset(model,threshold=3,size=100)
print(bad_pictures)
# Out:
# This picture has some problem: cat.0.jpg
# ./train\cat.0.jpg
# This picture has some problem: cat.1001.jpg
# ./train\cat.1001.jpg
# This picture has some problem: cat.10015.jpg
# ./train\cat.10015.jpg
# This picture has some problem: cat.10024.jpg
# ./train\cat.10024.jpg
# This picture has some problem: cat.10025.jpg
# ./train\cat.10025.jpg
# This picture has some problem: cat.10029.jpg
# ./train\cat.10029.jpg
# This picture has some problem: cat.10037.jpg
# ./train\cat.10037.jpg
# This picture has some problem: cat.1004.jpg
# ./train\cat.1004.jpg
# This picture has some problem: cat.10050.jpg
# ./train\cat.10050.jpg
# This picture has some problem: cat.10051.jpg
# ./train\cat.10051.jpg
# This picture has some problem: cat.10058.jpg
# ./train\cat.10058.jpg
# This picture has some problem: cat.1006.jpg
# ./train\cat.1006.jpg
# This picture has some problem: cat.10062.jpg
# ./train\cat.10062.jpg
# This picture has some problem: cat.10065.jpg
# ./train\cat.10065.jpg
# This picture has some problem: cat.10069.jpg
# ./train\cat.10069.jpg
# This picture has some problem: cat.10076.jpg
# ./train\cat.10076.jpg
# This picture has some problem: cat.10084.jpg
# ./train\cat.10084.jpg
# This picture has some problem: cat.10090.jpg
# ./train\cat.10090.jpg
# ['./train\\cat.0.jpg', './train\\cat.1001.jpg', './train\\cat.10015.jpg', './train\\cat.10024.jpg', './train\\cat.10025.jpg', './train\\cat.10029.jpg', './train\\cat.10037.jpg', './train\\cat.1004.jpg', './train\\cat.10050.jpg', './train\\cat.10051.jpg', './train\\cat.10058.jpg', './train\\cat.1006.jpg', './train\\cat.10062.jpg', './train\\cat.10065.jpg', './train\\cat.10069.jpg', './train\\cat.10076.jpg', './train\\cat.10084.jpg', './train\\cat.10090.jpg']

# %%
#使用XInception来预测图片属于种类
from keras.applications.xception import Xception
from keras.applications.xception import preprocess_input,decode_predictions

model_xception=Xception(include_top=False,weights='imagenet')
image_path='cat.0.jpg'
